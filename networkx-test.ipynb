# %%
import networkx as nx 
import matplotlib.pyplot as plt 
import numpy as np
# Out:
# Bad key "text.kerning_factor" on line 4 in
# E:\Softwares\Anaconda\envs\torch_env\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test_patch.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution

# %%
tree = nx.random_tree(n=20,seed=2021)

# %%
nx.draw(tree,with_labels=True)
plt.show()

# %%
b_tree = nx.balanced_tree(2,3)

# %%
nx.draw(b_tree,with_labels=True)
plt.show()

# %%
bn_tree = nx.binomial_tree(3)

# %%
nx.draw(bn_tree,with_labels=True)
plt.show()

# %%
frtree = nx.full_rary_tree(4,30)

# %%
frtree = nx.full_rary_tree(4,30)
nx.draw(frtree,with_labels=True)
plt.show()

# %%
def func(g,target):

# %%
paths
# Out:
# 1

# %%
frtree

# %%
nx.draw(frtree,with_labels=True)
plt.show()

# %%
frtree.remove_node(4)

# %%
nx.draw(frtree,with_labels=True)
plt.show()

# %%
def func(g):
    q = copy.deepcopy(g)
    q.remove_node(1)

# %%
nx.draw(frtree,with_labels=True)
plt.show()

# %%
import copy
func(frtree)

# %%
nx.draw(frtree,with_labels=True)
plt.show()

# %%
frtree = nx.full_rary_tree(3,20)
nx.draw(frtree,with_labels=True)
plt.show()

# %%
graph = nx.gnp_random_graph(10,0.3)

# %%
nx.draw(graph,with_labels=True)
plt.show()

# %%
list(nx.all_neighbors(graph,0))
# Out:
# [5, 8]
